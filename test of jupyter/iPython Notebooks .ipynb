# %%
pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in /Users/jatuporn/.pyenv/versions/3.12.0/lib/python3.12/site-packages (23.2.1)
# Collecting pip
#   Obtaining dependency information for pip from https://files.pythonhosted.org/packages/de/f0/c81e05b613866b76d2d1066490adf1a3dbc4ee9d9c839961c3fc8a6997af/pip-26.0.1-py3-none-any.whl.metadata
#   Downloading pip-26.0.1-py3-none-any.whl.metadata (4.7 kB)
# Downloading pip-26.0.1-py3-none-any.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 8.4 MB/s eta 0:00:007.8 MB/s eta 0:00:01
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 23.2.1
#     Uninstalling pip-23.2.1:
#       Successfully uninstalled pip-23.2.1
# Successfully installed pip-26.0.1
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install numpy==1.26.4
# Out:
# Collecting numpy==1.26.4
#   Downloading numpy-1.26.4-cp312-cp312-macosx_11_0_arm64.whl.metadata (61 kB)
# Downloading numpy-1.26.4-cp312-cp312-macosx_11_0_arm64.whl (13.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.7/13.7 MB 21.8 MB/s  0:00:00 eta 0:00:01:01:01
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.2.0
#     Uninstalling numpy-2.2.0:
#       Successfully uninstalled numpy-2.2.0
# Successfully installed numpy-1.26.4
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install h5py==3.11.0
# Out:
# Collecting h5py==3.11.0
#   Downloading h5py-3.11.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (2.5 kB)
# Requirement already satisfied: numpy>=1.17.3 in /Users/jatuporn/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from h5py==3.11.0) (1.26.4)
# Downloading h5py-3.11.0-cp312-cp312-macosx_11_0_arm64.whl (2.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 3.6 MB/s  0:00:002.9 MB/s eta 0:00:01:01
# Installing collected packages: h5py
# Successfully installed h5py-3.11.0
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install matplotlib==3.8.4
# Out:
# Collecting matplotlib==3.8.4
#   Downloading matplotlib-3.8.4-cp312-cp312-macosx_11_0_arm64.whl.metadata (5.8 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/jatuporn/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from matplotlib==3.8.4) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /Users/jatuporn/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from matplotlib==3.8.4) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/jatuporn/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from matplotlib==3.8.4) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/jatuporn/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from matplotlib==3.8.4) (1.4.9)
# Requirement already satisfied: numpy>=1.21 in /Users/jatuporn/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from matplotlib==3.8.4) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /Users/jatuporn/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from matplotlib==3.8.4) (25.0)
# Requirement already satisfied: pillow>=8 in /Users/jatuporn/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from matplotlib==3.8.4) (12.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/jatuporn/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from matplotlib==3.8.4) (3.3.1)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/jatuporn/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from matplotlib==3.8.4) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /Users/jatuporn/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib==3.8.4) (1.17.0)
# Downloading matplotlib-3.8.4-cp312-cp312-macosx_11_0_arm64.whl (7.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.5/7.5 MB 1.2 MB/s  0:00:06a 0:00:01m eta 0:00:01
# Installing collected packages: matplotlib
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.9.3
#     Uninstalling matplotlib-3.9.3:
#       Successfully uninstalled matplotlib-3.9.3
# Successfully installed matplotlib-3.8.4
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import matplotlib.pyplot as plt
import h5py
# %matplotlib inline

# %%
print ("hello world")
# Out:
# hello world
