# %%
import numpy as np
import matplotlib.pyplot as plt
import h5py
import time
# %matplotlib inline

# %%
np.random.seed(42)

# %%
# กำหนกภาำที่ต้องการสอน(Train) และเทส(Test) และจำนวน Pixel

m_train = 200
m_test = 50
nx = 12288

# จำลอง Feature แบบสุ่มค่าสี
x_train = np.random.randn(nx, m_train)*0.01 #ที่ต้องคูณ 0.1 ก็เพื่อให้ตัว model มีสเกลที่เล็กลงเช่นจาก 1.5 -> 0.5
x_test = np.random.randn(nx, m_test)*0.01

 # จำลอง Y Label แบบสุ่ม ถ้าไม่ใช่แมว 0 ถ้าเป็นแมว 1
y_train = np.random.randint(0,2, size=(1,m_train))
y_test = np.random.randint(0,2, size=(1,m_test))

print (f"ขนาดของ X_train: {x_train.shape}")
print (f"ขนาดของ Y_train: {y_test.shape}")
# Out:
# ขนาดของ X_train: (12288, 200)
# ขนาดของ Y_train: (1, 50)
